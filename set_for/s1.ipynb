# %%
sdata1 = {'a','b','c','a'}

print(sdata1)
# Out:
# {'b', 'a', 'c'}

# %%
sdata1[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 sdata1[0]
#
# TypeError: 'set' object is not subscriptable

# %%
for v in sdata1:
    print(v)
# Out:
# b
# a
# c

# %%
sdata1.add('new Value')

for v in sdata1:
    print(v)
# Out:
# new Value
# b
# a
# c

# %%
sdata1.remove("new Value")   # error if not found
sdata1.discard("apple")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 sdata1.remove("new Value")   # error if not found
#       2 sdata1.discard("apple")
#
# KeyError: 'new Value'

# %%
s1 = {1,2,3,3,8}
s2 = {1,2,3,5}

print(f"union = {s1 | s2}")
print(f"intersect = {s1 & s2}")
print(f"Difference = {s1 - s2}")
print(f"Difference = {s2 - s1}")
# Out:
# union = {1, 2, 3, 5, 8}
# intersect = {8, 1, 2, 3}
# Difference = set()
# Difference = {5}

# %%
fs = frozenset([1, 2, 3,6,1])
print(type(fs), fs)
# Out:
# <class 'frozenset'> frozenset({1, 2, 3, 6})
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 3
#       1 fs = frozenset([1, 2, 3,6,1])
#       2 print(type(fs), fs)
# ----> 3 fs[0]= 1
#
# TypeError: 'frozenset' object does not support item assignment
