# %%
l1 = [
    'a','b','c', 
    {
    'username' : 'arc',
    'batch':25
    }, 
    [1,2,3]
    , True, False
]

# %%
print('for loop started')

for l1Value in l1:
    print(l1Value, type(l1Value))
    print('-'*5)
print('for loop end')
# Out:
# for loop started
# a <class 'str'>
# -----
# b <class 'str'>
# -----
# c <class 'str'>
# -----
# {'username': 'arc', 'batch': 25} <class 'dict'>
# -----
# [1, 2, 3] <class 'list'>
# -----
# True <class 'bool'>
# -----
# False <class 'bool'>
# -----
# for loop end

# %%
print(f" l1[0] = {l1[0]} , type of l1[0] = {type(l1[0])}")
print(f" l1[1] = {l1[1]} , type of l1[1] = {type(l1[1])}")
print(f" l1[2] = {l1[2]} , type of l1[2] = {type(l1[2])}")
print(f" l1[3] = {l1[3]} , type of l1[3] = {type(l1[3])}")
print(f" l1[4] = {l1[4]} , type of l1[4] = {type(l1[4])}")
print(f" l1[5] = {l1[5]} , type of l1[5] = {type(l1[5])}")
print(f" l1[6] = {l1[6]} , type of l1[6] = {type(l1[6])}")
# print(f" l1[7] = {l1[7]} , type of l1[7] = {type(l1[7])}")
# Out:
#  l1[0] = a , type of l1[0] = <class 'str'>
#  l1[1] = b , type of l1[1] = <class 'str'>
#  l1[2] = c , type of l1[2] = <class 'str'>
#  l1[3] = {'username': 'arc', 'batch': 25} , type of l1[3] = <class 'dict'>
#  l1[4] = [1, 2, 3] , type of l1[4] = <class 'list'>
#  l1[5] = True , type of l1[5] = <class 'bool'>
#  l1[6] = False , type of l1[6] = <class 'bool'>
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[12], line 8
#       6 print(f" l1[5] = {l1[5]} , type of l1[5] = {type(l1[5])}")
#       7 print(f" l1[6] = {l1[6]} , type of l1[6] = {type(l1[6])}")
# ----> 8 print(f" l1[7] = {l1[7]} , type of l1[7] = {type(l1[7])}")
#
# IndexError: list index out of range

# %% [markdown]
# ## this is wrong logic

# %%
l2 = list(range(1,100))

for l2Value in l2:
    currentVlaue = l2Value # 2
    nextValue = currentVlaue + l2Value # 2+2 = 4
    print(f' currentValue = {currentVlaue}, nextValue  = { nextValue } , l2Value = {l2Value}')
    print()
# Out:
#  currentValue = 1, nextValue  = 2 , l2Value = 1
#
#  currentValue = 2, nextValue  = 4 , l2Value = 2
#
#  currentValue = 3, nextValue  = 6 , l2Value = 3
#
#  currentValue = 4, nextValue  = 8 , l2Value = 4
#
#  currentValue = 5, nextValue  = 10 , l2Value = 5
#
#  currentValue = 6, nextValue  = 12 , l2Value = 6
#
#  currentValue = 7, nextValue  = 14 , l2Value = 7
#
#  currentValue = 8, nextValue  = 16 , l2Value = 8
#
#  currentValue = 9, nextValue  = 18 , l2Value = 9
#
#  currentValue = 10, nextValue  = 20 , l2Value = 10
#
#  currentValue = 11, nextValue  = 22 , l2Value = 11
#
#  currentValue = 12, nextValue  = 24 , l2Value = 12
#
#  currentValue = 13, nextValue  = 26 , l2Value = 13
#
#  currentValue = 14, nextValue  = 28 , l2Value = 14
#
#  currentValue = 15, nextValue  = 30 , l2Value = 15
#
#  currentValue = 16, nextValue  = 32 , l2Value = 16
#
#  currentValue = 17, nextValue  = 34 , l2Value = 17
#
#  currentValue = 18, nextValue  = 36 , l2Value = 18
#
#  currentValue = 19, nextValue  = 38 , l2Value = 19
#
#  currentValue = 20, nextValue  = 40 , l2Value = 20
#
#  currentValue = 21, nextValue  = 42 , l2Value = 21
#
#  currentValue = 22, nextValue  = 44 , l2Value = 22
#
#  currentValue = 23, nextValue  = 46 , l2Value = 23
#
#  currentValue = 24, nextValue  = 48 , l2Value = 24
#
#  currentValue = 25, nextValue  = 50 , l2Value = 25
#
#  currentValue = 26, nextValue  = 52 , l2Value = 26
#
#  currentValue = 27, nextValue  = 54 , l2Value = 27
#
#  currentValue = 28, nextValue  = 56 , l2Value = 28
#
#  currentValue = 29, nextValue  = 58 , l2Value = 29
#
#  currentValue = 30, nextValue  = 60 , l2Value = 30
#
#  currentValue = 31, nextValue  = 62 , l2Value = 31
#
#  currentValue = 32, nextValue  = 64 , l2Value = 32
#
#  currentValue = 33, nextValue  = 66 , l2Value = 33
#
#  currentValue = 34, nextValue  = 68 , l2Value = 34
#
#  currentValue = 35, nextValue  = 70 , l2Value = 35
#
#  currentValue = 36, nextValue  = 72 , l2Value = 36
#
#  currentValue = 37, nextValue  = 74 , l2Value = 37
#
#  currentValue = 38, nextValue  = 76 , l2Value = 38
#
#  currentValue = 39, nextValue  = 78 , l2Value = 39
#
#  currentValue = 40, nextValue  = 80 , l2Value = 40
#
#  currentValue = 41, nextValue  = 82 , l2Value = 41
#
#  currentValue = 42, nextValue  = 84 , l2Value = 42
#
#  currentValue = 43, nextValue  = 86 , l2Value = 43
#
#  currentValue = 44, nextValue  = 88 , l2Value = 44
#
#  currentValue = 45, nextValue  = 90 , l2Value = 45
#
#  currentValue = 46, nextValue  = 92 , l2Value = 46
#
#  currentValue = 47, nextValue  = 94 , l2Value = 47
#
#  currentValue = 48, nextValue  = 96 , l2Value = 48
#
#  currentValue = 49, nextValue  = 98 , l2Value = 49
#
#  currentValue = 50, nextValue  = 100 , l2Value = 50
#
#  currentValue = 51, nextValue  = 102 , l2Value = 51
#
#  currentValue = 52, nextValue  = 104 , l2Value = 52
#
#  currentValue = 53, nextValue  = 106 , l2Value = 53
#
#  currentValue = 54, nextValue  = 108 , l2Value = 54
#
#  currentValue = 55, nextValue  = 110 , l2Value = 55
#
#  currentValue = 56, nextValue  = 112 , l2Value = 56
#
#  currentValue = 57, nextValue  = 114 , l2Value = 57
#
#  currentValue = 58, nextValue  = 116 , l2Value = 58
#
#  currentValue = 59, nextValue  = 118 , l2Value = 59
#
#  currentValue = 60, nextValue  = 120 , l2Value = 60
#
#  currentValue = 61, nextValue  = 122 , l2Value = 61
#
#  currentValue = 62, nextValue  = 124 , l2Value = 62
#
#  currentValue = 63, nextValue  = 126 , l2Value = 63
#
#  currentValue = 64, nextValue  = 128 , l2Value = 64
#
#  currentValue = 65, nextValue  = 130 , l2Value = 65
#
#  currentValue = 66, nextValue  = 132 , l2Value = 66
#
#  currentValue = 67, nextValue  = 134 , l2Value = 67
#
#  currentValue = 68, nextValue  = 136 , l2Value = 68
#
#  currentValue = 69, nextValue  = 138 , l2Value = 69
#
#  currentValue = 70, nextValue  = 140 , l2Value = 70
#
#  currentValue = 71, nextValue  = 142 , l2Value = 71
#
#  currentValue = 72, nextValue  = 144 , l2Value = 72
#
#  currentValue = 73, nextValue  = 146 , l2Value = 73
#
#  currentValue = 74, nextValue  = 148 , l2Value = 74
#
#  currentValue = 75, nextValue  = 150 , l2Value = 75
#
#  currentValue = 76, nextValue  = 152 , l2Value = 76
#
#  currentValue = 77, nextValue  = 154 , l2Value = 77
#
#  currentValue = 78, nextValue  = 156 , l2Value = 78
#
#  currentValue = 79, nextValue  = 158 , l2Value = 79
#
#  currentValue = 80, nextValue  = 160 , l2Value = 80
#
#  currentValue = 81, nextValue  = 162 , l2Value = 81
#
#  currentValue = 82, nextValue  = 164 , l2Value = 82
#
#  currentValue = 83, nextValue  = 166 , l2Value = 83
#
#  currentValue = 84, nextValue  = 168 , l2Value = 84
#
#  currentValue = 85, nextValue  = 170 , l2Value = 85
#
#  currentValue = 86, nextValue  = 172 , l2Value = 86
#
#  currentValue = 87, nextValue  = 174 , l2Value = 87
#
#  currentValue = 88, nextValue  = 176 , l2Value = 88
#
#  currentValue = 89, nextValue  = 178 , l2Value = 89
#
#  currentValue = 90, nextValue  = 180 , l2Value = 90
#
#  currentValue = 91, nextValue  = 182 , l2Value = 91
#
#  currentValue = 92, nextValue  = 184 , l2Value = 92
#
#  currentValue = 93, nextValue  = 186 , l2Value = 93
#
#  currentValue = 94, nextValue  = 188 , l2Value = 94
#
#  currentValue = 95, nextValue  = 190 , l2Value = 95
#
#  currentValue = 96, nextValue  = 192 , l2Value = 96
#
#  currentValue = 97, nextValue  = 194 , l2Value = 97
#
#  currentValue = 98, nextValue  = 196 , l2Value = 98
#
#  currentValue = 99, nextValue  = 198 , l2Value = 99

# %% [markdown]
# ## correct logic

# %%
l2 = list(range(1,100))

prvValue  = 0

for l2Value in l2:
    currentAdd = prvValue + l2Value
    prvValue = currentAdd
    print(f' prvValue = {prvValue}, currentAdd  = { currentAdd } , l2Value = {l2Value}')
    print()
# Out:
#  prvValue = 1, currentAdd  = 1 , l2Value = 1
#
#  prvValue = 3, currentAdd  = 3 , l2Value = 2
#
#  prvValue = 6, currentAdd  = 6 , l2Value = 3
#
#  prvValue = 10, currentAdd  = 10 , l2Value = 4
#
#  prvValue = 15, currentAdd  = 15 , l2Value = 5
#
#  prvValue = 21, currentAdd  = 21 , l2Value = 6
#
#  prvValue = 28, currentAdd  = 28 , l2Value = 7
#
#  prvValue = 36, currentAdd  = 36 , l2Value = 8
#
#  prvValue = 45, currentAdd  = 45 , l2Value = 9
#
#  prvValue = 55, currentAdd  = 55 , l2Value = 10
#
#  prvValue = 66, currentAdd  = 66 , l2Value = 11
#
#  prvValue = 78, currentAdd  = 78 , l2Value = 12
#
#  prvValue = 91, currentAdd  = 91 , l2Value = 13
#
#  prvValue = 105, currentAdd  = 105 , l2Value = 14
#
#  prvValue = 120, currentAdd  = 120 , l2Value = 15
#
#  prvValue = 136, currentAdd  = 136 , l2Value = 16
#
#  prvValue = 153, currentAdd  = 153 , l2Value = 17
#
#  prvValue = 171, currentAdd  = 171 , l2Value = 18
#
#  prvValue = 190, currentAdd  = 190 , l2Value = 19
#
#  prvValue = 210, currentAdd  = 210 , l2Value = 20
#
#  prvValue = 231, currentAdd  = 231 , l2Value = 21
#
#  prvValue = 253, currentAdd  = 253 , l2Value = 22
#
#  prvValue = 276, currentAdd  = 276 , l2Value = 23
#
#  prvValue = 300, currentAdd  = 300 , l2Value = 24
#
#  prvValue = 325, currentAdd  = 325 , l2Value = 25
#
#  prvValue = 351, currentAdd  = 351 , l2Value = 26
#
#  prvValue = 378, currentAdd  = 378 , l2Value = 27
#
#  prvValue = 406, currentAdd  = 406 , l2Value = 28
#
#  prvValue = 435, currentAdd  = 435 , l2Value = 29
#
#  prvValue = 465, currentAdd  = 465 , l2Value = 30
#
#  prvValue = 496, currentAdd  = 496 , l2Value = 31
#
#  prvValue = 528, currentAdd  = 528 , l2Value = 32
#
#  prvValue = 561, currentAdd  = 561 , l2Value = 33
#
#  prvValue = 595, currentAdd  = 595 , l2Value = 34
#
#  prvValue = 630, currentAdd  = 630 , l2Value = 35
#
#  prvValue = 666, currentAdd  = 666 , l2Value = 36
#
#  prvValue = 703, currentAdd  = 703 , l2Value = 37
#
#  prvValue = 741, currentAdd  = 741 , l2Value = 38
#
#  prvValue = 780, currentAdd  = 780 , l2Value = 39
#
#  prvValue = 820, currentAdd  = 820 , l2Value = 40
#
#  prvValue = 861, currentAdd  = 861 , l2Value = 41
#
#  prvValue = 903, currentAdd  = 903 , l2Value = 42
#
#  prvValue = 946, currentAdd  = 946 , l2Value = 43
#
#  prvValue = 990, currentAdd  = 990 , l2Value = 44
#
#  prvValue = 1035, currentAdd  = 1035 , l2Value = 45
#
#  prvValue = 1081, currentAdd  = 1081 , l2Value = 46
#
#  prvValue = 1128, currentAdd  = 1128 , l2Value = 47
#
#  prvValue = 1176, currentAdd  = 1176 , l2Value = 48
#
#  prvValue = 1225, currentAdd  = 1225 , l2Value = 49
#
#  prvValue = 1275, currentAdd  = 1275 , l2Value = 50
#
#  prvValue = 1326, currentAdd  = 1326 , l2Value = 51
#
#  prvValue = 1378, currentAdd  = 1378 , l2Value = 52
#
#  prvValue = 1431, currentAdd  = 1431 , l2Value = 53
#
#  prvValue = 1485, currentAdd  = 1485 , l2Value = 54
#
#  prvValue = 1540, currentAdd  = 1540 , l2Value = 55
#
#  prvValue = 1596, currentAdd  = 1596 , l2Value = 56
#
#  prvValue = 1653, currentAdd  = 1653 , l2Value = 57
#
#  prvValue = 1711, currentAdd  = 1711 , l2Value = 58
#
#  prvValue = 1770, currentAdd  = 1770 , l2Value = 59
#
#  prvValue = 1830, currentAdd  = 1830 , l2Value = 60
#
#  prvValue = 1891, currentAdd  = 1891 , l2Value = 61
#
#  prvValue = 1953, currentAdd  = 1953 , l2Value = 62
#
#  prvValue = 2016, currentAdd  = 2016 , l2Value = 63
#
#  prvValue = 2080, currentAdd  = 2080 , l2Value = 64
#
#  prvValue = 2145, currentAdd  = 2145 , l2Value = 65
#
#  prvValue = 2211, currentAdd  = 2211 , l2Value = 66
#
#  prvValue = 2278, currentAdd  = 2278 , l2Value = 67
#
#  prvValue = 2346, currentAdd  = 2346 , l2Value = 68
#
#  prvValue = 2415, currentAdd  = 2415 , l2Value = 69
#
#  prvValue = 2485, currentAdd  = 2485 , l2Value = 70
#
#  prvValue = 2556, currentAdd  = 2556 , l2Value = 71
#
#  prvValue = 2628, currentAdd  = 2628 , l2Value = 72
#
#  prvValue = 2701, currentAdd  = 2701 , l2Value = 73
#
#  prvValue = 2775, currentAdd  = 2775 , l2Value = 74
#
#  prvValue = 2850, currentAdd  = 2850 , l2Value = 75
#
#  prvValue = 2926, currentAdd  = 2926 , l2Value = 76
#
#  prvValue = 3003, currentAdd  = 3003 , l2Value = 77
#
#  prvValue = 3081, currentAdd  = 3081 , l2Value = 78
#
#  prvValue = 3160, currentAdd  = 3160 , l2Value = 79
#
#  prvValue = 3240, currentAdd  = 3240 , l2Value = 80
#
#  prvValue = 3321, currentAdd  = 3321 , l2Value = 81
#
#  prvValue = 3403, currentAdd  = 3403 , l2Value = 82
#
#  prvValue = 3486, currentAdd  = 3486 , l2Value = 83
#
#  prvValue = 3570, currentAdd  = 3570 , l2Value = 84
#
#  prvValue = 3655, currentAdd  = 3655 , l2Value = 85
#
#  prvValue = 3741, currentAdd  = 3741 , l2Value = 86
#
#  prvValue = 3828, currentAdd  = 3828 , l2Value = 87
#
#  prvValue = 3916, currentAdd  = 3916 , l2Value = 88
#
#  prvValue = 4005, currentAdd  = 4005 , l2Value = 89
#
#  prvValue = 4095, currentAdd  = 4095 , l2Value = 90
#
#  prvValue = 4186, currentAdd  = 4186 , l2Value = 91
#
#  prvValue = 4278, currentAdd  = 4278 , l2Value = 92
#
#  prvValue = 4371, currentAdd  = 4371 , l2Value = 93
#
#  prvValue = 4465, currentAdd  = 4465 , l2Value = 94
#
#  prvValue = 4560, currentAdd  = 4560 , l2Value = 95
#
#  prvValue = 4656, currentAdd  = 4656 , l2Value = 96
#
#  prvValue = 4753, currentAdd  = 4753 , l2Value = 97
#
#  prvValue = 4851, currentAdd  = 4851 , l2Value = 98
#
#  prvValue = 4950, currentAdd  = 4950 , l2Value = 99
