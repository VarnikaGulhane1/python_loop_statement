# %%
tdata1 = ('a', 'b', 'c', 'd')

print(f"tdata1 = {tdata1}, type of tdata1 = {type(tdata1)}, len od tdata1 = {len(tdata1)}")
# Out:
# tdata1 = ('a', 'b', 'c', 'd'), type of tdata1 = <class 'tuple'>, len od tdata1 = 4

# %%
print(f"tdata1[0] = {tdata1[0]}, type of tdata1[0] = {type(tdata1[0])}")
print(f"tdata1[1] = {tdata1[1]}, type of tdata1[1] = {type(tdata1[1])}")
print(f"tdata1[2] = {tdata1[2]}, type of tdata1[2] = {type(tdata1[2])}")
print(f"tdata1[3] = {tdata1[3]}, type of tdata1[3] = {type(tdata1[3])}")
print(f"tdata1[4] = {tdata1[4]}, type of tdata1[4] = {type(tdata1[4])}")
# Out:
# tdata1[0] = a, type of tdata1[0] = <class 'str'>
# tdata1[1] = b, type of tdata1[1] = <class 'str'>
# tdata1[2] = c, type of tdata1[2] = <class 'str'>
# tdata1[3] = d, type of tdata1[3] = <class 'str'>
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[3], line 5
#       3 print(f"tdata1[2] = {tdata1[2]}, type of tdata1[2] = {type(tdata1[2])}")
#       4 print(f"tdata1[3] = {tdata1[3]}, type of tdata1[3] = {type(tdata1[3])}")
# ----> 5 print(f"tdata1[4] = {tdata1[4]}, type of tdata1[4] = {type(tdata1[4])}")
#
# IndexError: tuple index out of range

# %%
print(f"tdata1[0] = {tdata1[0]} before change")

tdata1[0] = 'new value'

print(f"tdata1[0] = {tdata1[0]}, after change")
# Out:
# tdata1[0] = a before change
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 print(f"tdata1[0] = {tdata1[0]} before change")
# ----> 3 tdata1[0] = 'new value'
#       5 print(f"tdata1[0] = {tdata1[0]}, after change")
#
# TypeError: 'tuple' object does not support item assignment

# %%
print(tdata1[0:1])
print(tdata1[-1])
# Out:
# ('a',)
# d

# %%
tdata1 = 'complete change'
print(tdata1)
# Out:
# complete change

# %%
tdata2 = ('g', 1, {"name": 'arc'}, [1, 2, 3])

print(tdata2[2].get('name'))
# Out:
# arc

# %%
print(type(tdata2))

tdata2 = list(tdata2)

print(type(tdata2))
# Out:
# <class 'tuple'>
# <class 'list'>

# %%
tdata3 = ('a', 'b', 'c', 'a')

print(tdata3)
# Out:
# ('a', 'b', 'c', 'a')
